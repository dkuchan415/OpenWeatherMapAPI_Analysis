# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import gmaps.datasets
import json

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
#use jupyter gmaps

file = "..\WeatherPy\output_data\city_weather.csv"
vaca_df = pd.read_csv(file)
vaca_df.head()
# Out:
#                       City Country    Lat     Lng  Max Temp  Humidity  \
# 0                   Atuona      PF  -9.80 -139.03     78.01        74
# 1                    Bluff      NZ -46.60  168.33     57.00        60
# 2                    Yumen      CN  40.28   97.20     47.19        41
# 3  Santa Vitória do Palmar      BR -33.52  -53.37     58.12        75
# 4            Mount Gambier      AU -37.83  140.77     59.00        72
#
#    Cloudiness  Wind Speed        Date
# 0          75       15.43  1603241225
# 1          84        7.00  1603241787
# 2           0        7.34  1603241788
# 3         100       11.99  1603241789
# 4          90        9.17  1603241790

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
#Configure Gmaps

gmaps.configure(api_key=g_key)

#Create coordinates and humidity list

locations = vaca_df[['Lat', 'Lng']].astype(float)

humidity = vaca_df['Humidity'].astype(float)

#Create for loop to add Lat, Lng, and humidty for each city

# cities = vaca_df['City']
# city_name = []
# lat = []
# lng = []
# humidity = []

# for city in cities:
#     city_name.append(vaca_df['City'])
#     lat.append(vaca_df['Lat'])
#     lng.append(vaca_df['Lng'])
#     humidity.append(vaca_df['Humidity'])

figure_layout = {
    'width': '400px',
    'height': '300px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
fig = gmaps.figure(layout=figure_layout)

# Assign the marker layer to a variable

heat_layer=gmaps.heatmap_layer(locations, humidity, dissipating=True, max_intensity=100, point_radius=10)

# Add the layer to the map
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='300px', margin='0 auto 0 auto', padding='1px', wi…

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
#cut unneeded columns
hotel_df = vaca_df.dropna(how='any')

hotel_df = hotel_df.loc[(hotel_df['Max Temp'] < 85) &
                       (hotel_df['Max Temp'] > 75) &
                       (hotel_df['Cloudiness'] < 15) &
                       (hotel_df['Wind Speed'] < 5)]
len(hotel_df)
# Out:
# 11

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
#Day 3 activity 4, iterate through df and search for hotel by coordinates

hotel_df['Hotel Name'] = ""

#Add goople places base url

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

#Set base parameters

params = {"radius": "5000",
        "type": "lodging",
        "key": g_key,
}
for index, row in hotel_df.iterrows():
    lat_lng = f"{row['Lat']},{row['Lng']}"
    params['location'] = lat_lng
    response = requests.get(base_url, params=params).json()
    print(json.dumps(response, indent=4))
#plot markers = name of hotel- use jupyter gmaps
    hotel_df.loc[index, 'Hotel Name'] = response['results'][0]['name']
# change map options and adjusting

#use weighted heat map
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "CqQCHAEAABG8SeBR51NtU7TSCfD_oUDfPXFawM5srKR2i1NCUsmbgiwt3KxTONWLW2nPhJPOgAB8c93j09t5S4Wpz1QDuE5IPWktGBHDPqoKTGXro2JcI2twhBFH6OLezcQwHJ3DKX14lVJVhVp0v5e8Pez1iHiV6y-ylNFEy7ccCmUlDsHygwVM-5jercYwtZ99KTQd75GeauqVyruolTwTM9WSAnZ8lrdyKl3Y0Ae2Bf2MoI_5TarR6Aoc6BQNiQW8AJviXhBXiGBXWYeOV4KNetGgDr8oHh6WTY-1N-fdWun371Q0GlAbEajaLRYOk4ZzjrzMSw8UI-Y5IMdHFBuHZg3LKbpcrJhrrYkgje33005eUwLn2zseRvjtKnEviR_TVM5ZzxIQue95AlhvdcSJbIJZEwylUxoUCyOX5gl1NYMIMLd1LamzqpzR3cA",
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 17.0193409,
#                     "lng": 54.0610108
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 17.02056453029151,
#                         "lng": 54.0624392302915
#                     },
#                     "southwest": {
#                         "lat": 17.0178665697085,
#                         "lng": 54.0597412697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "HAMDAN PLAZA HOTEL",
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112935328687369630840\">Hafsa Alharbi</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAvcRvzqMoQpE9jqYZgI5iCwpDOFWAJUKZnCsxlWUYuEjlDS4_DT9GzldlUcQAUQAfJlL1_A9DjtQEN77ZXt2MKwMFAr-u1sZhSiTuvACdEkDYEKeV0cBDINXplkdiVIm8EhAJ_WiUUkopCSEiPDn2C-2qGhTZI60nV9gaLt1r7-8mAFPIMuk0pw",
#                     "width": 3024
#                 }
#             ],
#             "place_id": "ChIJfcmTanVg0T0RVP-fvHfooVk",
#             "plus_code": {
#                 "compound_code": "2396+PC Salalah, Oman",
#                 "global_code": "7H9P2396+PC"
#             },
#             "rating": 3.8,
#             "reference": "ChIJfcmTanVg0T0RVP-fvHfooVk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 499,
#             "vicinity": "Salalah"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 17.0192763,
#                     "lng": 54.09484399999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 17.0205921302915,
#                         "lng": 54.09606043029149
#                     },
#                     "southwest": {
#                         "lat": 17.01789416970849,
#                         "lng": 54.0933624697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "City Hotel",
#             "photos": [
#                 {
#                     "height": 3456,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/118370767415665313099\">\u041c\u0430\u0440\u0438\u044f \u0420\u042b\u041a\u041e\u0412\u0410</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAYNsgrJt12uzDA51elKx4xiJnbF_cOa1Ziij09XSBc_hGHIwH6WUi7_0Llh0uLWBW6n3caTK6QXsxET_3I4huhln-NHks-oZw1l546kO4ZhlhLT2Swm4GdUr70gVmtnseEhABbf7Yr8UbPBy7WCwHL71NGhRxIj3O8IrQXVbHOaXuU338VrZLTg",
#                     "width": 4608
#                 }
#             ],
#             "place_id": "ChIJued8uPrf0z0R9o2L8tkxbJ8",
#             "plus_code": {
#                 "compound_code": "239V+PW Salalah, Oman",
#                 "global_code": "7H9P239V+PW"
#             },
#             "rating": 3.8,
#             "reference": "ChIJued8uPrf0z0R9o2L8tkxbJ8",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 351,
#             "vicinity": "Near Sultan Qaboose Masjid, Salalah"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 17.0105353,
#                     "lng": 54.07813059999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 17.01196043029151,
#                         "lng": 54.07945553029149
#                     },
#                     "southwest": {
#                         "lat": 17.0092624697085,
#                         "lng": 54.0767575697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Darbat Hotel",
#             "photos": [
#                 {
#                     "height": 1520,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106308831748732655380\">Mafiz Chowdhury</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAaoCo47Ey4BtXwdqaxniJbVkYmrKwUSi6c6P-Tl9A7EnJspcBStDK5tsXNoIRnqp61bn6yR0_gb9kzs39_NXmXg28gjzZ2brtIBUqPD8ZqbODbAiDe5ejkdiopD9YS52yEhCKkh6FJFnvCSZpHtHAhqiEGhS8ed59JgbZQmF4ti-z98RNp-5aTg",
#                     "width": 2688
#                 }
#             ],
#             "place_id": "ChIJtXoZfhlg0T0RGbG7bLZwFlE",
#             "plus_code": {
#                 "compound_code": "236H+67 Salalah, Oman",
#                 "global_code": "7H9P236H+67"
#             },
#             "rating": 3.6,
#             "reference": "ChIJtXoZfhlg0T0RGbG7bLZwFlE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 639,
#             "vicinity": "23rd July Street, Salalah"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 17.0149102,
#                     "lng": 54.0919116
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 17.0163751302915,
#                         "lng": 54.0932091302915
#                     },
#                     "southwest": {
#                         "lat": 17.0136771697085,
#                         "lng": 54.0905111697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Muscat International Hotel plaza Salalah",
#             "photos": [
#                 {
#                     "height": 972,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115686906749923816454\">Muscat International Hotel</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAj00pk6jYiVZOHpg3etsQR7noIPaHV96ttnN2fO7hZ5refE7dPJDs8-qcZgRUwbt4MK9aSEeNqaC2dzpALKlbsGHsjnHMjeSPybInJVdi58eSFtONMnV6c7oO-NxLzvwhEhD--7PQFEZt3II_KktTx3vFGhRA7LAznIjAWH7RQxCiGmCsPvac1Q",
#                     "width": 1728
#                 }
#             ],
#             "place_id": "ChIJV90jHvHf0z0R3ArGjoFcPEk",
#             "plus_code": {
#                 "compound_code": "237R+XQ Salalah, Oman",
#                 "global_code": "7H9P237R+XQ"
#             },
#             "rating": 3.9,
#             "reference": "ChIJV90jHvHf0z0R3ArGjoFcPEk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 493,
#             "vicinity": "23rd July Street, Salalah"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 17.0173176,
#                     "lng": 54.0827537
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 17.0186816802915,
#                         "lng": 54.0841008302915
#                     },
#                     "southwest": {
#                         "lat": 17.0159837197085,
#                         "lng": 54.0814028697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Alrehab Palace 1",
#             "photos": [
#                 {
#                     "height": 605,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114198330678931473255\">NOFAL SOLTANI</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAXxNlxSzix5_-rdpLUdSk7yqWeT4pyPgMPAowL8R6mW32_IWOoXk3LmldDcrWesOG8vzJ4RQN3QO8gzMeM4bITg_r14pckjilnizbJsIe_HAPa-oMxSRttlXbzBFut0mCEhCU-d9z9sGu5hygvn4duQYSGhSvJ6jJ0Vr773AweJDC9SwgkJTkUQ",
#                     "width": 805
#                 }
#             ],
#             "place_id": "ChIJKbqA7wJg0T0RJqtgyHolLd0",
#             "plus_code": {
#                 "compound_code": "238M+W4 Salalah, Oman",
#                 "global_code": "7H9P238M+W4"
#             },
#             "rating": 3.9,
#             "reference": "ChIJKbqA7wJg0T0RJqtgyHolLd0",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 11,
#             "vicinity": "Salalah Al Jadida Street - 23 July, Salalah"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 17.0192508,
#                     "lng": 54.0651637
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 17.0205492302915,
#                         "lng": 54.06653058029151
#                     },
#                     "southwest": {
#                         "lat": 17.0178512697085,
#                         "lng": 54.06383261970851
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Jawharet Al Kheir Furnished Apartments",
#             "photos": [
#                 {
#                     "height": 2592,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108528728989429895864\">Rabab Qasam</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAdT9Duzhy4Fjshvv5TgwloFh_0hFVKn54Co7_n30eajx6xHGCQBrm6efd7VE5rpBdjWbTyDUGIkojkiQFucjJYkBqEwh7bLIxmB49dJX2RXjaBxzvfqZWzdY615smV7QiEhBitqDV7s_mSlpsFkuuFW-HGhTvEjxjICR_oQtwHr2zx_qC2ofsvA",
#                     "width": 4608
#                 }
#             ],
#             "place_id": "ChIJM9iGBAtg0T0Ro6MVo4Er73A",
#             "plus_code": {
#                 "compound_code": "2398+P3 Salalah, Oman",
#                 "global_code": "7H9P2398+P3"
#             },
#             "rating": 3.9,
#             "reference": "ChIJM9iGBAtg0T0Ro6MVo4Er73A",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 302,
#             "vicinity": "37, 13067 Al Noman Street, Salalah"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 17.0153888,
#                     "lng": 54.1097914
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 17.0167420802915,
#                         "lng": 54.1111107302915
#                     },
#                     "southwest": {
#                         "lat": 17.0140441197085,
#                         "lng": 54.1084127697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Al Nasr Hotel",
#             "photos": [
#                 {
#                     "height": 1080,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101932199184940049041\">Aslam Faraj</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAddQENUcnOsYQJtY0xdOUK0Z_r-wAeUHPzJPNpBUfYs7lvA9XHrk_cDYe2UN0YGNU-XLL1YCeKNookQfqEFaEICp4d0gywRJqzsby-u1kgJrun7ix--aZ2EU0UOZ6XZdZEhBFSgjr6XAyQhAwWNv9kcKpGhT2_SQvLNUGF5FWtB6sBIZEWvDlrA",
#                     "width": 1080
#                 }
#             ],
#             "place_id": "ChIJiZr8QRvg0z0RUguzleULByg",
#             "plus_code": {
#                 "compound_code": "2485+5W Salalah, Oman",
#                 "global_code": "7H9P2485+5W"
#             },
#             "rating": 3.1,
#             "reference": "ChIJiZr8QRvg0z0RUguzleULByg",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 86,
#             "vicinity": "Airport Street Salalah, \u0635\u0644\u0627\u0644\u0629"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 17.0183457,
#                     "lng": 54.0958335
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 17.0197935802915,
#                         "lng": 54.09715793029149
#                     },
#                     "southwest": {
#                         "lat": 17.0170956197085,
#                         "lng": 54.0944599697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Eman House",
#             "photos": [
#                 {
#                     "height": 768,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106388477955534517321\">\u0627\u0646\u0627 \u0645\u0633\u0644\u0645</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAiXxVHq32FAlvyL3YeeLsRZ-8ybeaVr5vV9wKStdNnxlxGZ_wrLVlEO3aN4vtwXTNuzKrATYj9-TUwyGKk8z0n0Y3HsQTNAty34DnV9R1OLWXszXN450x_A-zcoj3O6bMEhDooKRaH5Ko4AjNBa8JvneNGhR-YtGa4AfleG5Avs-LNc5k3LBZ5Q",
#                     "width": 1024
#                 }
#             ],
#             "place_id": "ChIJRcsFVeXf0z0Res7EG9heXiI",
#             "plus_code": {
#                 "compound_code": "239W+88 Salalah, Oman",
#                 "global_code": "7H9P239W+88"
#             },
#             "rating": 3.8,
#             "reference": "ChIJRcsFVeXf0z0Res7EG9heXiI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 30,
#             "vicinity": "Opposit KM mall, next to Sultan Qaboos Mousque P.O 4, Salalah"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 17.0074884,
#                     "lng": 54.068749
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 17.0087488302915,
#                         "lng": 54.0701294302915
#                     },
#                     "southwest": {
#                         "lat": 17.0060508697085,
#                         "lng": 54.0674314697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Atlas Salalah 1",
#             "place_id": "ChIJq6qaqxZg0T0Rb2bR8McgcpI",
#             "plus_code": {
#                 "compound_code": "2349+XF Salalah, Oman",
#                 "global_code": "7H9P2349+XF"
#             },
#             "reference": "ChIJq6qaqxZg0T0Rb2bR8McgcpI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "\u0645\u0628\u0646\u0649 \u062f\u0627\u0631 \u0633\u0627\u0644\u0645 \u0645\u0642\u0627\u0628\u0644 \u062f\u0648\u0627\u0631 \u0627\u0644\u0646\u062c\u0627\u062d, \u0634\u0627\u0631\u0639 \u0645\u0631\u0643\u0632 \u0627\u0644\u0645\u062d\u0627\u0641\u0638\u0629, Salalah"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 17.0233925,
#                     "lng": 54.0673377
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 17.0245461302915,
#                         "lng": 54.0687661802915
#                     },
#                     "southwest": {
#                         "lat": 17.02184816970849,
#                         "lng": 54.0660682197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Gateway Salalah Apartments",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2400,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110481615393320646629\">gateway salalah</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAQkjHlLBqAY3woxiIS3P3uvEFm5aHbnwLQI-YP7HxNgHfaLvuu-A8AHBTxV4mtjo64xa0Vm7VhUxFKDvVUrodZbyYZ-cgCVK7qVSFtgNzEmcW7u9IE6gVpYpzxBOt3pD7EhCxj40zcGZDCMGTKW87LiE4GhTpZ1Ch9m17vY83wenFRROR7RvgnQ",
#                     "width": 3600
#                 }
#             ],
#             "place_id": "ChIJp542zOFf0T0RSs-Ab86_99M",
#             "plus_code": {
#                 "compound_code": "23F8+9W Salalah, Oman",
#                 "global_code": "7H9P23F8+9W"
#             },
#             "rating": 3.8,
#             "reference": "ChIJp542zOFf0T0RSs-Ab86_99M",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 63,
#             "vicinity": "Ar Rubat Street, Near Salalah Galdens Mall, Salalah"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 17.0506493,
#                     "lng": 54.10659039999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 17.0520415302915,
#                         "lng": 54.1079248802915
#                     },
#                     "southwest": {
#                         "lat": 17.0493435697085,
#                         "lng": 54.1052269197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "\u0623\u0631\u062c\u0627\u0646 \u0644\u0644\u0634\u0642\u0642 \u0627\u0644\u0641\u0646\u062f\u0642\u064a\u0629 Arjaan hotel apartments",
#             "place_id": "ChIJEVVVVRXg0z0RyQOc5zNE3wM",
#             "plus_code": {
#                 "compound_code": "3424+7J Salalah, Oman",
#                 "global_code": "7H9P3424+7J"
#             },
#             "reference": "ChIJEVVVVRXg0z0RyQOc5zNE3wM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "\u0634\u0627\u0631\u0639 \u0627\u0644\u0645\u062c\u062f, Salalah"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 17.015973,
#                     "lng": 54.0997629
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 17.0173093302915,
#                         "lng": 54.1010447302915
#                     },
#                     "southwest": {
#                         "lat": 17.0146113697085,
#                         "lng": 54.0983467697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "\u062c\u0646\u0627\u062a \u0644\u0644\u0634\u0642\u0642 \u0627\u0644\u0645\u0641\u0631\u0648\u0634\u0629",
#             "place_id": "ChIJvwdvzejf0z0RxkA4XsSY48c",
#             "plus_code": {
#                 "compound_code": "238X+9W Salalah, Oman",
#                 "global_code": "7H9P238X+9W"
#             },
#             "rating": 5,
#             "reference": "ChIJvwdvzejf0z0RxkA4XsSY48c",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "OM, \u0634\u0627\u0631\u0639 \u064a\u0648\u0644\u064a\u0648 \u0662\u0663, \u0635\u0644\u0627\u0644\u0629"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 17.0181826,
#                     "lng": 54.0848246
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 17.0195002302915,
#                         "lng": 54.0861768302915
#                     },
#                     "southwest": {
#                         "lat": 17.0168022697085,
#                         "lng": 54.0834788697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Star Emirates Apartments 2",
#             "photos": [
#                 {
#                     "height": 1200,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100452197239672972995\">Reservation Star Emirates</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAq7MJtWpYtDm-Ty06M3J9Kz_to7Y96PWHmJQOn5IDNCcFf91ohtSzXGis2GZNRt8bQxHGaauRuM-Ui2DGwTZkaOO9AVasQuTBiv4SXbgFW9wl1YatZ8-CH9NUe3VcrsQTEhAQCZNw-lI4_D67_4xzyDI7GhS1XL4ji3tZxY9KDMLHsany_xPYWA",
#                     "width": 1800
#                 }
#             ],
#             "place_id": "ChIJVVVVVQJg0T0RdwTm37dLGZ8",
#             "plus_code": {
#                 "compound_code": "239M+7W Salalah, Oman",
#                 "global_code": "7H9P239M+7W"
#             },
#             "rating": 3.5,
#             "reference": "ChIJVVVVVQJg0T0RdwTm37dLGZ8",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 101,
#             "vicinity": "Near Oman UAE Exchange, 211 Al Najah Street, Salalah"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 17.0188219,
#                     "lng": 54.0973251
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 17.0201470302915,
#                         "lng": 54.0985803302915
#                     },
#                     "southwest": {
#                         "lat": 17.0174490697085,
#                         "lng": 54.0958823697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Al Dyafa Hotel Suites",
#             "photos": [
#                 {
#                     "height": 1440,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104976759202695751469\">Marek Duch\u00e1\u010dek</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA7bO9mcGA35EmSWeVW61tSXFiLcdSxBF6bIUJ0L69trRocYP2sORxldbrMnb2ERAsGQD5UZgovlbUavQqwDICho-RuYfD44WAqKXtxTaUxXx0KoScoEZ9NkRgqOYpVbbbEhBr5eKPaEjXPSf2_qLxBJxoGhQYfCtVPSIpRrSRYx5hxzkloOBhqg",
#                     "width": 2560
#                 }
#             ],
#             "place_id": "ChIJEY5LYeXf0z0RVygHv5YYFmo",
#             "plus_code": {
#                 "compound_code": "239W+GW Salalah, Oman",
#                 "global_code": "7H9P239W+GW"
#             },
#             "rating": 3.7,
#             "reference": "ChIJEY5LYeXf0z0RVygHv5YYFmo",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 294,
#             "vicinity": "214 central market, \u0635\u0644\u0627\u0644\u0629"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 17.017287,
#                     "lng": 54.08262469999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 17.0186046802915,
#                         "lng": 54.0839774302915
#                     },
#                     "southwest": {
#                         "lat": 17.0159067197085,
#                         "lng": 54.0812794697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "\u0645\u0646\u0627\u0632\u0644 \u0637\u064a\u0628\u0647 \u0644\u0644\u0634\u0642\u0642 \u0627\u0644\u0645\u0641\u0631\u0648\u0634\u0647",
#             "photos": [
#                 {
#                     "height": 4160,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116571271214976041429\">Amit Tiwari</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAEvJ1DCDp1LCXDRSB3cCbnCGSbrJUBbY-sqzsKk3a6usTJwIgyo32sBbz-TN8ZJhIFbHX60pZ64lNrMv6ELcz0XvVTTQspDHVVuTcdTB6ayrUV5SZsRyNfe5WiO2IQZp9EhCLvXRHUtGXsmlMieGMmLnxGhRtEnfwuIFErN1S-A3Gta2kLcBNLA",
#                     "width": 3120
#                 }
#             ],
#             "place_id": "ChIJ_48I5QJg0T0RTVbHfcIC3vs",
#             "plus_code": {
#                 "compound_code": "238M+W2 Salalah, Oman",
#                 "global_code": "7H9P238M+W2"
#             },
#             "rating": 3.7,
#             "reference": "ChIJ_48I5QJg0T0RTVbHfcIC3vs",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 34,
#             "vicinity": "Salalah Al Jadidah Street, Salalah"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 17.0192225,
#                     "lng": 54.1047129
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 17.0206565302915,
#                         "lng": 54.1060405302915
#                     },
#                     "southwest": {
#                         "lat": 17.0179585697085,
#                         "lng": 54.1033425697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Pearl Salalah",
#             "place_id": "ChIJwSAAb-jf0z0R8GXfDxf8G9c",
#             "plus_code": {
#                 "compound_code": "2493+MV Salalah, Oman",
#                 "global_code": "7H9P2493+MV"
#             },
#             "rating": 3.7,
#             "reference": "ChIJwSAAb-jf0z0R8GXfDxf8G9c",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 40,
#             "vicinity": "Salalah"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 17.0198228,
#                     "lng": 54.1098936
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 17.0211642302915,
#                         "lng": 54.11118098029149
#                     },
#                     "southwest": {
#                         "lat": 17.0184662697085,
#                         "lng": 54.10848301970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "OYO 115 Star Emirates Furnished Apartment",
#             "photos": [
#                 {
#                     "height": 480,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106685509317902755066\">OYO 115 Star Emirates Furnished Apartment</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAD0eDoZaj1CWIWssVF0P9FEsXQDJOZINFev5nRPA0eyEwrhJRM1ChGgJKnd_UoGGEFFNojtXv8JQ9y0cVEj9Z03zCCyIzCsnj3kmQs7KFeNZ6HjrMbvCNYqeQ7EaZwoDKEhDGq4mitW4a0tLpC8F3SH99GhT7MjzkNbk6FE984DEKj1HI1B2GoA",
#                     "width": 640
#                 }
#             ],
#             "place_id": "ChIJ7yQhzvnf0z0RkUwaTuOnWJ4",
#             "plus_code": {
#                 "compound_code": "2495+WX Salalah, Oman",
#                 "global_code": "7H9P2495+WX"
#             },
#             "rating": 4,
#             "reference": "ChIJ7yQhzvnf0z0RkUwaTuOnWJ4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 88,
#             "vicinity": "Bank Maisarah, 155, Near, Al Jadidha Street, Salalah"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 17.0109741,
#                     "lng": 54.067638
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 17.0123076302915,
#                         "lng": 54.06899203029149
#                     },
#                     "southwest": {
#                         "lat": 17.0096096697085,
#                         "lng": 54.0662940697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Ajwan Hotels Apartments in salalah",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2592,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112816837318701661748\">Ramanathan Sundaram</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA0ZVxpUoHGqfOekxvH4MsLOGwpq60sX84dTh_MjuqLXhj1xmd4GzSpJZABwR3hzuhAUMWSYVGdzM_mEQrzAwC1v-MN1GzsRrAU3avIiHK-Ks28KPM0405qCgctgmWtXcTEhAElIhsHGI_fV93Xwx_U5TKGhQKn4LD65l8dI0F-pJRLWMvYgwpnQ",
#                     "width": 4608
#                 }
#             ],
#             "place_id": "ChIJvTGkFhJg0T0RyrMQBZa_JV0",
#             "plus_code": {
#                 "compound_code": "2369+93 Salalah, Oman",
#                 "global_code": "7H9P2369+93"
#             },
#             "rating": 3.8,
#             "reference": "ChIJvTGkFhJg0T0RyrMQBZa_JV0",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 265,
#             "vicinity": "Mirbat Street, Salalah"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 17.0506495,
#                     "lng": 54.106591
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 17.05204173029151,
#                         "lng": 54.1079254302915
#                     },
#                     "southwest": {
#                         "lat": 17.0493437697085,
#                         "lng": 54.1052274697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Shmokh Al Ezz Hotel Apartment",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "place_id": "ChIJVVVVVRXg0z0RJUunWHP-bnU",
#             "plus_code": {
#                 "compound_code": "3424+7J Salalah, Oman",
#                 "global_code": "7H9P3424+7J"
#             },
#             "reference": "ChIJVVVVVRXg0z0RJUunWHP-bnU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Salalah"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 17.0131437,
#                     "lng": 54.0845796
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 17.01454453029151,
#                         "lng": 54.08591968029149
#                     },
#                     "southwest": {
#                         "lat": 17.0118465697085,
#                         "lng": 54.08322171970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "\u0623\u0631\u0634 \u0644\u0644\u0634\u0642\u0642 \u0627\u0644\u0641\u0646\u062f\u0642\u064a\u0629",
#             "place_id": "ChIJxbQ6gR1g0T0R_q6bbkenoLQ",
#             "plus_code": {
#                 "compound_code": "237M+7R Salalah, Oman",
#                 "global_code": "7H9P237M+7R"
#             },
#             "reference": "ChIJxbQ6gR1g0T0R_q6bbkenoLQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "OM, \u0634\u0627\u0631\u0639 \u064a\u0648\u0644\u064a\u0648 \u0662\u0663, \u0635\u0644\u0627\u0644\u0629"
#         }
#     ],
#     "status": "OK"
# }
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 29.939216,
#                     "lng": -91.76727799999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.9408403302915,
#                         "lng": -91.76581656970849
#                     },
#                     "southwest": {
#                         "lat": 29.9381423697085,
#                         "lng": -91.76851453029151
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "back to back rv park",
#             "photos": [
#                 {
#                     "height": 530,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110736522856146831017\">back to back rv park</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAJvKvSzn_G2s4JW4MPCx29VpKoDnesUmuzMU9axS7Nrw0uI_XOZSxWWPgoLs3RZVVV3sJnfR8DHBwgp1ve_MTu5odh4pEThIl0hw1tbxyk-5mbv_Wcm7M559sQA_V1eTdEhDtedS2EQrGv7OEpO0zqAuDGhSH1TnuZnpVSFEImWrxJixozbp4Lg",
#                     "width": 800
#                 }
#             ],
#             "place_id": "ChIJbwvY_TmdI4YRglwibrSdpYE",
#             "plus_code": {
#                 "compound_code": "W6QM+M3 New Iberia, LA, USA",
#                 "global_code": "76XCW6QM+M3"
#             },
#             "rating": 3.3,
#             "reference": "ChIJbwvY_TmdI4YRglwibrSdpYE",
#             "scope": "GOOGLE",
#             "types": [
#                 "rv_park",
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 4,
#             "vicinity": "5912 highway 90 east or 8419, Louisiana 14, New Iberia"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 29.966189,
#                     "lng": -91.7285509
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.9678544302915,
#                         "lng": -91.7269319197085
#                     },
#                     "southwest": {
#                         "lat": 29.9651564697085,
#                         "lng": -91.72962988029151
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "OLIVE BRANCH COTTAGES",
#             "place_id": "ChIJ1az1ZsyEI4YRX_WFqV-cv60",
#             "plus_code": {
#                 "compound_code": "X78C+FH New Iberia, LA, USA",
#                 "global_code": "76XCX78C+FH"
#             },
#             "rating": 1,
#             "reference": "ChIJ1az1ZsyEI4YRX_WFqV-cv60",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "6008 Old Jeanerette Road, New Iberia"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 29.989921,
#                     "lng": -91.771737
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.99139058029149,
#                         "lng": -91.77033056970849
#                     },
#                     "southwest": {
#                         "lat": 29.98869261970849,
#                         "lng": -91.77302853029151
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "The Bayou Pool House",
#             "place_id": "ChIJt6c4bGuDI4YRUmB6wwtqn7U",
#             "plus_code": {
#                 "compound_code": "X6QH+X8 New Iberia, LA, USA",
#                 "global_code": "76XCX6QH+X8"
#             },
#             "rating": 5,
#             "reference": "ChIJt6c4bGuDI4YRUmB6wwtqn7U",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 3,
#             "vicinity": "4216 South Drive, New Iberia"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 29.9329483,
#                     "lng": -91.72331969999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.93444248029149,
#                         "lng": -91.72188421970849
#                     },
#                     "southwest": {
#                         "lat": 29.9317445197085,
#                         "lng": -91.72458218029149
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Little Pond",
#             "place_id": "ChIJ0wcymBibI4YRk1aopgh-2dE",
#             "plus_code": {
#                 "compound_code": "W7MG+5M Jeanerette, LA, USA",
#                 "global_code": "76XCW7MG+5M"
#             },
#             "reference": "ChIJ0wcymBibI4YRk1aopgh-2dE",
#             "scope": "GOOGLE",
#             "types": [
#                 "rv_park",
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "8104 East Admiral Doyle Drive, Jeanerette"
#         }
#     ],
#     "status": "OK"
# }
# {
#     "html_attributions": [],
#     "next_page_token": "CqQCHAEAADP0qwreadGt1ctyH7CS36gQMVD5aflkfyS2SceJxvF_Jrc2BXf4Rprb5aUKi1jw84CUoCeh8sIL6zkxSSX8bYFJLK725o5Znlu5iOV4TCLXVu5776akn6WETxEBXm7g_Cui4_hchz9bOlNyd44UcR9767AoeISnNCPyg7zQISfAF50HppmXfufJ65Png1DfEzhRUg4y1oDO1YBRYE02wkqFUi9-0s13EBII4d2DsU7V2GUev_-RLe1fEe9R8JDMlbjxj144VpqyWcgpa5_o1YLgi-utzxNjBQ2ATMvJAix7w1VLC4CZKYGNWgsjOMwUNhHBgKxYh-ocn2o06YYYMhcDglUYLb_UK3Txo9La50F94VgVQZoU7IGOJsGdqz46VRIQwpuHJ6l1d83cIayfCscVUxoUEBMKygmat5FFduvfjmir0HBruV0",
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -9.878055600000001,
#                     "lng": -56.0977778
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -9.876889719708497,
#                         "lng": -56.0958162697085
#                     },
#                     "southwest": {
#                         "lat": -9.879587680291502,
#                         "lng": -56.09851423029149
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Floresta Amazonica Hotel",
#             "photos": [
#                 {
#                     "height": 4016,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107610506465200698001\">Floresta Amazonica Hotel</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA3ZVlCbzTiyISX3--ZzapIBF11hVm9tIg-vO62WNA0bjoiutQBJa41wiryH4qv06tZagpTruzuTPv9OA2ibC_4smIjCtOQM_eb7R6EBkvTzEg_qlNWmyQQtq1GdtUj74zEhD9x-oKFiTCqk00dW3ITy5ZGhTN1gGwEknidsVm56cSWWwPffYvUg",
#                     "width": 6016
#                 }
#             ],
#             "place_id": "ChIJT-VvAZwxqpMRTtdqmDqNHZs",
#             "plus_code": {
#                 "compound_code": "4WC2+QV E, Alta Floresta - State of Mato Grosso, Brazil",
#                 "global_code": "68254WC2+QV"
#             },
#             "rating": 4.5,
#             "reference": "ChIJT-VvAZwxqpMRTtdqmDqNHZs",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 413,
#             "vicinity": "Avenida Perimetral, Avenida Ns Oeste, 2001, Alta Floresta"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -9.8732488,
#                     "lng": -56.0834026
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -9.871828469708499,
#                         "lng": -56.0822822197085
#                     },
#                     "southwest": {
#                         "lat": -9.874526430291501,
#                         "lng": -56.0849801802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Estoril",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1536,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105872619894181024266\">Jocivan da Cruz Santos</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA7mKDS7zwAlmQqIUSqyQOhrKOL1D7Vp_O6u3zoIv7DAnRNoo0hMervdGdB5uL62eICuOT8PbuNUw7Wa4-W3A26GSqofNe8mqFQNQuLYTOVo15CNX-BcXv8mw5wBKg4yNoEhDqs51YJPpWIWBzmtkRrrgSGhQufv0ul7XyImx6Fl_WLhPfZ_6zNw",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJV7Ez1H0wqpMR3ieCnOZadF4",
#             "plus_code": {
#                 "compound_code": "4WG8+PJ B, Alta Floresta - State of Mato Grosso, Brazil",
#                 "global_code": "68254WG8+PJ"
#             },
#             "rating": 4,
#             "reference": "ChIJV7Ez1H0wqpMR3ieCnOZadF4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 68,
#             "vicinity": "Avenida Ludovico da Riva Neto, 2950 - B, Alta Floresta"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -9.8909611,
#                     "lng": -56.08626659999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -9.889689369708497,
#                         "lng": -56.0850341197085
#                     },
#                     "southwest": {
#                         "lat": -9.892387330291502,
#                         "lng": -56.0877320802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Luz Divina",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1960,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/118186183120429597630\">Hotel Luz Divina</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAivuY3QuR9y9mGJEtXBd4zJCPxIPRxr4tx6dfnHurJzT5EsvgV85_a3v40TAujcQXxW5xn8yXkggttbkfZgDrO3PBXmWH1Pacxm5bMuAbGtHya5hG5SLEoF67dVvXd9_EEhB6a4Wv-dheNFr4rnrfrkE0GhQO0_Ub3KppAF1467pdC0hMBPzfmg",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJhYOQcKcxqpMRgPv5fiaqy58",
#             "plus_code": {
#                 "compound_code": "4W57+JF J, Alta Floresta - State of Mato Grosso, Brazil",
#                 "global_code": "68254W57+JF"
#             },
#             "rating": 4.1,
#             "reference": "ChIJhYOQcKcxqpMRgPv5fiaqy58",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 151,
#             "vicinity": "Avenida Ludovico da Riva Neto, N\u00b01006 - Centro, Alta Floresta"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -9.8756884,
#                     "lng": -56.0885962
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -9.874200719708499,
#                         "lng": -56.08720486970849
#                     },
#                     "southwest": {
#                         "lat": -9.876898680291502,
#                         "lng": -56.08990283029149
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Lisboa Palace Hotel",
#             "opening_hours": {
# ...
#                 "establishment"
#             ],
#             "user_ratings_total": 143,
#             "vicinity": "Avenida Doutor Hugo de Mendon\u00e7a, 436 - Com\u00e9rcio, Itaituba"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -4.2742935,
#                     "lng": -55.9830554
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -4.273042169708497,
#                         "lng": -55.98164266970851
#                     },
#                     "southwest": {
#                         "lat": -4.275740130291502,
#                         "lng": -55.98434063029151
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Planalto",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110691876011990992865\">Hotel Planalto</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAua07rKU2V0W2Qg_zOJzHptiL34Xus8wTvZEUQB1qYwK8taoPvnmURDMhG6_46mg-SOLVceICNPjADRAEzSKF4nUprHSXjXCVpf-SjNBigLfwgma9yi7yn-F8ZJbDuE1cEhDzKzsyMtThGMvxxfUz4WmCGhTeA38qEMmugV2OZtl4s4f1ff3VNQ",
#                     "width": 3024
#                 }
#             ],
#             "place_id": "ChIJ09isIefbX5IRJq4ccw9e-YQ",
#             "plus_code": {
#                 "compound_code": "P2G8+7Q Centro, Itaituba - State of Par\u00e1, Brazil",
#                 "global_code": "6876P2G8+7Q"
#             },
#             "rating": 4.6,
#             "reference": "ChIJ09isIefbX5IRJq4ccw9e-YQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 5,
#             "vicinity": "Av Justo Chermont, 35. Esquina com, Avenida Doutor Hugo de Mendon\u00e7a - Centro, Itaituba"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -4.2757816,
#                     "lng": -55.9849414
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -4.274450269708499,
#                         "lng": -55.9835811197085
#                     },
#                     "southwest": {
#                         "lat": -4.277148230291503,
#                         "lng": -55.9862790802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "HOTEL CAMPOS",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 491,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102336226300350126326\">Eliane Ara\u00fajo Campos</a>"
#                     ],
#                     "photo_reference": "CmRaAAAApFcE7fqrukT0p3wJOYODojrWYIbsapG1zSc8vfgzQ4eWKjekVkyeVW-jvTDIaEeIhMOv4CAEmArJIy_6VyCW3T4c4lxbyaBEEXxIbFunQMl3QBxV4IdACsJD7LLCnE9eEhBi2uazBW2pyvJwZxpAnkWGGhRUcjWRlQZSeuDgFBk6yS7s67aHHg",
#                     "width": 750
#                 }
#             ],
#             "place_id": "ChIJxXBKIk7bX5IRwtuzHF5lA7o",
#             "plus_code": {
#                 "compound_code": "P2F8+M2 Com\u00e9rcio, Itaituba - State of Par\u00e1, Brazil",
#                 "global_code": "6876P2F8+M2"
#             },
#             "rating": 4.1,
#             "reference": "ChIJxXBKIk7bX5IRwtuzHF5lA7o",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 97,
#             "vicinity": "Travessa Victor Campos Com, Avenida Doutor Hugo de Mendon\u00e7a - Com\u00e9rcio, Itaituba"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -4.2753483,
#                     "lng": -55.9845421
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -4.274075969708498,
#                         "lng": -55.9831397197085
#                     },
#                     "southwest": {
#                         "lat": -4.276773930291503,
#                         "lng": -55.98583768029149
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel piaui",
#             "photos": [
#                 {
#                     "height": 3120,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109639439883477566910\">valdecy correia</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAy7moc8hXsr4Tz7Iny9MY8DJOO-B1NV1Tv_8Bc2rFa15_E8gB0EfesEkggT-T6MOIMb0saZTEo9mFHZ-SsEvaL_vJU73a3ivIl7WW9zzd28kFQYM7-kYfAkvz0QMYY5U1EhDXGcHs3Qnv1NxISeglqwnlGhSMoCE49qN3OdAk_-ktVW176FGW2g",
#                     "width": 4160
#                 }
#             ],
#             "place_id": "ChIJ4dS6ii3aX5IRsKeNqNQVL9U",
#             "plus_code": {
#                 "compound_code": "P2F8+V5 Com\u00e9rcio, Itaituba - State of Par\u00e1, Brazil",
#                 "global_code": "6876P2F8+V5"
#             },
#             "rating": 3.9,
#             "reference": "ChIJ4dS6ii3aX5IRsKeNqNQVL9U",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 138,
#             "vicinity": "1045, Avenida Doutor Hugo de Mendon\u00e7a, 973 - Com\u00e9rcio, Itaituba"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -4.2730941,
#                     "lng": -55.97974259999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -4.271849369708498,
#                         "lng": -55.9782902197085
#                     },
#                     "southwest": {
#                         "lat": -4.274547330291503,
#                         "lng": -55.9809881802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Riozinho",
#             "photos": [
#                 {
#                     "height": 2336,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107798022658735618088\">Jayno Gon\u00e7alves Salgado</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAffvkypSUAc-sRtr-XVNjFIAqt-ntQgwezGswH8oAgGYzIuutgTzQwFluDWZqWbmfONJ41Gf02XlhF8KL3j1njDK8X76Hw4eHkkSJNrvRgY_s62bVvAiaE17Q315M_X6CEhCipR8EijFaWRQLziN_NxSuGhRGVQOlel-J4sc3vb5OPcTNou9yrg",
#                     "width": 4160
#                 }
#             ],
#             "place_id": "ChIJ3YTe0NLbX5IRI1a2hJHygyA",
#             "plus_code": {
#                 "compound_code": "P2GC+Q4 Centro, Itaituba - State of Par\u00e1, Brazil",
#                 "global_code": "6876P2GC+Q4"
#             },
#             "rating": 3.8,
#             "reference": "ChIJ3YTe0NLbX5IRI1a2hJHygyA",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 153,
#             "vicinity": "Avenida S\u00e3o Jos\u00e9, 77 - Centro, Itaituba"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -4.273424200000001,
#                     "lng": -55.98220019999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -4.272081669708498,
#                         "lng": -55.98086181970849
#                     },
#                     "southwest": {
#                         "lat": -4.274779630291502,
#                         "lng": -55.98355978029149
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Pousada",
#             "place_id": "ChIJ3RjmGy3aX5IR2JOfmghWNKs",
#             "plus_code": {
#                 "compound_code": "P2G9+J4 Bela Vista, Itaituba - State of Par\u00e1, Brazil",
#                 "global_code": "6876P2G9+J4"
#             },
#             "rating": 5,
#             "reference": "ChIJ3RjmGy3aX5IR2JOfmghWNKs",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "314, Travessa Treze de Maio, 138 - Bela Vista, Itaituba"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -4.273072699999999,
#                     "lng": -55.979752
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -4.271802219708498,
#                         "lng": -55.97832561970851
#                     },
#                     "southwest": {
#                         "lat": -4.274500180291502,
#                         "lng": -55.98102358029151
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Phillips",
#             "photos": [
#                 {
#                     "height": 3120,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101153408992791033871\">Jameson Dahlin</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAB6Wg1m3YT4xEAKms5irr98AlrxS-2RmxOWH5RXzQqsBybHeO37iyC3WUp7cIJahGrd5wJRZ9xLsWoyrB4BFGPxD6gOD72PRy0firsAaton8dFhskhHFkiKOgT6BDZ4pYEhAxeTAbBGHsAJoog_zOjlfPGhR7e6jzI3bvbzMW3vK4Qiq-AReJmQ",
#                     "width": 4160
#                 }
#             ],
#             "place_id": "ChIJcQyP19LbX5IRtnRv0WGxlJY",
#             "plus_code": {
#                 "compound_code": "P2GC+Q3 Bela Vista, Itaituba - State of Par\u00e1, Brazil",
#                 "global_code": "6876P2GC+Q3"
#             },
#             "rating": 3.8,
#             "reference": "ChIJcQyP19LbX5IRtnRv0WGxlJY",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 23,
#             "vicinity": "133, Avenida S\u00e3o Jos\u00e9, 21 - Bela Vista, Itaituba"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -4.2732465,
#                     "lng": -55.98245199999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -4.271877169708498,
#                         "lng": -55.9810694197085
#                     },
#                     "southwest": {
#                         "lat": -4.274575130291502,
#                         "lng": -55.9837673802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Pousada Dona Deuza",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "place_id": "ChIJuS71HC3aX5IRGUQkGb_FB-A",
#             "plus_code": {
#                 "compound_code": "P2G9+P2 Centro, Itaituba - State of Par\u00e1, Brazil",
#                 "global_code": "6876P2G9+P2"
#             },
#             "rating": 3.7,
#             "reference": "ChIJuS71HC3aX5IRGUQkGb_FB-A",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 3,
#             "vicinity": "Travessa Treze de Maio, 201 - Centro, Itaituba"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -4.272694599999999,
#                     "lng": -55.98012790000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -4.271322969708497,
#                         "lng": -55.9787941697085
#                     },
#                     "southwest": {
#                         "lat": -4.274020930291502,
#                         "lng": -55.9814921302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Cacilda",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "place_id": "ChIJYT8OLNPbX5IReygxZMJxK3w",
#             "plus_code": {
#                 "compound_code": "P2G9+WW S\u00e3o Jos\u00e9, Itaituba - State of Par\u00e1, Brazil",
#                 "global_code": "6876P2G9+WW"
#             },
#             "reference": "ChIJYT8OLNPbX5IReygxZMJxK3w",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "S\u00e3o Jos\u00e9"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -4.2725124,
#                     "lng": -55.9796142
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -4.271101269708498,
#                         "lng": -55.97818536970849
#                     },
#                     "southwest": {
#                         "lat": -4.273799230291503,
#                         "lng": -55.98088333029149
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Juliana Park Hotel",
#             "photos": [
#                 {
#                     "height": 3096,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117101028584557221615\">jos\u00e9 nunes</a>"
#                     ],
#                     "photo_reference": "CmRaAAAANqAidQYaKbOS2pVEsHkNSXCnGHzIYmkSYr_a35ZLzVKm9mKslcFx6sJKsuArSGKnM9fE1vG0D1OncZB5LzTqU0RcB6BUTT1MT3N2Vgpwx9JNvq7kywgGMyz-2vxtBBdrEhCPvvnfSYSmPMaJpf1cUdQuGhTU0FfNs5BYBUKKfusoPvWJu6zKNg",
#                     "width": 4128
#                 }
#             ],
#             "place_id": "ChIJd49AJNPbX5IR-_dMR9YaFDM",
#             "plus_code": {
#                 "compound_code": "P2GC+X5 Bela Vista, Itaituba - State of Par\u00e1, Brazil",
#                 "global_code": "6876P2GC+X5"
#             },
#             "rating": 4.2,
#             "reference": "ChIJd49AJNPbX5IR-_dMR9YaFDM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 105,
#             "vicinity": "Travessa Jo\u00e3o Pessoa, 31 - Bela Vista, Itaituba"
#         }
#     ],
#     "status": "OK"
# }

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map

# Customize the size of the figure

# Assign the marker layer to a variable
markers = gmaps.marker_layer(locations)
#info_box_content=hotel_info
# Add the layer to the map
fig.add_layer(markers)
fig
# Display figure
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='300px', margin='0 auto 0 auto', padding='1px', wi…
